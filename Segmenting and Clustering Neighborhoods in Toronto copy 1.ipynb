# %% [markdown]
# ## I import all the required libraries for the code

# %%
from bs4 import BeautifulSoup

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# ## I pass the URL of the Wikipedia page to BeautifulSoup

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html_file=requests.get(url)
soup=BeautifulSoup(html_file.content, 'lxml')

# %%
print(soup.prettify())

# %% [markdown]
# ## This extracts the title of the webpage

# %%
print(soup.title.text)

# %% [markdown]
# ### Since we are interested in the data in the table, this next step extracts the required data from the webpage

# %%
table=soup.find('table', class_='wikitable')

# %% [markdown]
# ### I extract the table header from the "th" tag

# %%
#This extracts the columns, and passes them into a list
columns=[]

for i in table.find_all('th'):
    columns.append(i.text)
    
columns=[w.replace("\n",'') for w in columns]

columns

# %% [markdown]
# ### I extract the row data from the "td" tags

# %%
#This extracts the row data, and passes them into a list
rows=[]

for i in table.find_all('td'):
    rows.append(i.text)

rows=[w.replace("\n",'') for w in rows]

rows

# %%
#I reshape the row data to match the desired df
a=int(len(rows)/3)
x=np.reshape(rows, (a,3))

# %%
toronto_df=pd.DataFrame()
toronto_df=toronto_df.from_records(x, columns=columns)

# %%
toronto_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
toronto_df.shape
# Out:
# (289, 3)

# %%
toronto_df['Borough'].replace('Not assigned', np.NaN, inplace=True)
toronto_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A               NaN      Not assigned
# 1      M2A               NaN      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
toronto_df.dropna(subset=['Borough'], inplace=True)

# %%
toronto_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
toronto_df['Neighbourhood'].replace('Not assigned',toronto_df['Borough'], inplace=True)

# %%
toronto_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
foo=lambda a: "/".join(a)
toronto_df=toronto_df.groupby(['Postcode','Borough']).agg({'Neighbourhood': foo})

# %%
toronto_df.reset_index(inplace=True)

# %%
toronto_df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                        Rouge/Malvern
# 1                 Highland Creek/Rouge Hill/Port Union
# 2                      Guildwood/Morningside/West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6            East Birchmount Park/Ionview/Kennedy Park
# 7                        Clairlea/Golden Mile/Oakridge
# 8        Cliffcrest/Cliffside/Scarborough Village West
# 9                           Birch Cliff/Cliffside West
# 10   Dorset Park/Scarborough Town Centre/Wexford He...
# 11                                    Maryvale/Wexford
# 12                                           Agincourt
# 13               Clarks Corners/Sullivan/Tam O'Shanter
# 14   Agincourt North/L'Amoreaux East/Milliken/Steel...
# 15                        L'Amoreaux West/Steeles West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                          Fairview/Henry Farm/Oriole
# 19                                     Bayview Village
# 20                             Silver Hills/York Mills
# 21                              Newtonbrook/Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                     Flemingdon Park/Don Mills South
# 28       Bathurst Manor/Downsview North/Wilson Heights
# 29                      Northwood Park/York University
# 30                          CFB Toronto/Downsview East
# 31                                      Downsview West
# 32                                   Downsview Central
# 33                                 Downsview Northwest
# 34                                    Victoria Village
# 35                      Woodbine Gardens/Parkview Hill
# 36                                    Woodbine Heights
# 37                                         The Beaches
# 38                                             Leaside
# 39                                    Thorncliffe Park
# 40                                        East Toronto
# 41                         The Danforth West/Riverdale
# 42                       The Beaches West/India Bazaar
# 43                                     Studio District
# 44                                       Lawrence Park
# 45                                    Davisville North
# 46                                  North Toronto West
# 47                                          Davisville
# 48                          Moore Park/Summerhill East
# 49   Deer Park/Forest Hill SE/Rathnelly/South Hill/...
# 50                                            Rosedale
# 51                          Cabbagetown/St. James Town
# 52                                Church and Wellesley
# 53                            Harbourfront/Regent Park
# 54                             Ryerson/Garden District
# 55                                      St. James Town
# 56                                         Berczy Park
# 57                                  Central Bay Street
# 58                              Adelaide/King/Richmond
# 59     Harbourfront East/Toronto Islands/Union Station
# 60             Design Exchange/Toronto Dominion Centre
# 61                       Commerce Court/Victoria Hotel
# 62                    Bedford Park/Lawrence Manor East
# 63                                            Roselawn
# 64                  Forest Hill North/Forest Hill West
# 65                   The Annex/North Midtown/Yorkville
# 66                       Harbord/University of Toronto
# 67             Chinatown/Grange Park/Kensington Market
# 68   CN Tower/Bathurst Quay/Island airport/Harbourf...
# 69                     Stn A PO Boxes 25 The Esplanade
# 70               First Canadian Place/Underground city
# 71                     Lawrence Heights/Lawrence Manor
# 72                                           Glencairn
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                         Dovercourt Village/Dufferin
# 77                             Little Portugal/Trinity
# 78          Brockton/Exhibition Place/Parkdale Village
# 79              Maple Leaf Park/North Park/Upwood Park
# 80         Del Ray/Keelesdale/Mount Dennis/Silverthorn
# 81                        The Junction North/Runnymede
# 82                        High Park/The Junction South
# 83                               Parkdale/Roncesvalles
# 84                                   Runnymede/Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87    Business reply mail Processing Centre969 Eastern
# 88          Humber Bay Shores/Mimico South/New Toronto
# 89                               Alderwood/Long Branch
# 90         The Kingsway/Montgomery Road/Old Mill North
# 91   Humber Bay/King's Mill Park/Kingsway Park Sout...
# 92   Kingsway Park South West/Mimico NW/The Queensw...
# 93                                    Islington Avenue
# 94   Cloverdale/Islington/Martin Grove/Princess Gar...
# 95   Bloordale Gardens/Eringate/Markland Wood/Old B...
# 96                                       Humber Summit
# 97                                     Emery/Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village/Martin Grove Gardens/Richvie...
# 101  Albion Gardens/Beaumond Heights/Humbergate/Jam...
# 102                                          Northwest

# %%
toronto_df.shape
# Out:
# (103, 3)

# %%
toronto_df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                        Rouge/Malvern
# 1                 Highland Creek/Rouge Hill/Port Union
# 2                      Guildwood/Morningside/West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6            East Birchmount Park/Ionview/Kennedy Park
# 7                        Clairlea/Golden Mile/Oakridge
# 8        Cliffcrest/Cliffside/Scarborough Village West
# 9                           Birch Cliff/Cliffside West
# 10   Dorset Park/Scarborough Town Centre/Wexford He...
# 11                                    Maryvale/Wexford
# 12                                           Agincourt
# 13               Clarks Corners/Sullivan/Tam O'Shanter
# 14   Agincourt North/L'Amoreaux East/Milliken/Steel...
# 15                        L'Amoreaux West/Steeles West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                          Fairview/Henry Farm/Oriole
# 19                                     Bayview Village
# 20                             Silver Hills/York Mills
# 21                              Newtonbrook/Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                     Flemingdon Park/Don Mills South
# 28       Bathurst Manor/Downsview North/Wilson Heights
# 29                      Northwood Park/York University
# 30                          CFB Toronto/Downsview East
# 31                                      Downsview West
# 32                                   Downsview Central
# 33                                 Downsview Northwest
# 34                                    Victoria Village
# 35                      Woodbine Gardens/Parkview Hill
# 36                                    Woodbine Heights
# 37                                         The Beaches
# 38                                             Leaside
# 39                                    Thorncliffe Park
# 40                                        East Toronto
# 41                         The Danforth West/Riverdale
# 42                       The Beaches West/India Bazaar
# 43                                     Studio District
# 44                                       Lawrence Park
# 45                                    Davisville North
# 46                                  North Toronto West
# 47                                          Davisville
# 48                          Moore Park/Summerhill East
# 49   Deer Park/Forest Hill SE/Rathnelly/South Hill/...
# 50                                            Rosedale
# 51                          Cabbagetown/St. James Town
# 52                                Church and Wellesley
# 53                            Harbourfront/Regent Park
# 54                             Ryerson/Garden District
# 55                                      St. James Town
# 56                                         Berczy Park
# 57                                  Central Bay Street
# 58                              Adelaide/King/Richmond
# 59     Harbourfront East/Toronto Islands/Union Station
# 60             Design Exchange/Toronto Dominion Centre
# 61                       Commerce Court/Victoria Hotel
# 62                    Bedford Park/Lawrence Manor East
# 63                                            Roselawn
# 64                  Forest Hill North/Forest Hill West
# 65                   The Annex/North Midtown/Yorkville
# 66                       Harbord/University of Toronto
# 67             Chinatown/Grange Park/Kensington Market
# 68   CN Tower/Bathurst Quay/Island airport/Harbourf...
# 69                     Stn A PO Boxes 25 The Esplanade
# 70               First Canadian Place/Underground city
# 71                     Lawrence Heights/Lawrence Manor
# 72                                           Glencairn
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                         Dovercourt Village/Dufferin
# 77                             Little Portugal/Trinity
# 78          Brockton/Exhibition Place/Parkdale Village
# 79              Maple Leaf Park/North Park/Upwood Park
# 80         Del Ray/Keelesdale/Mount Dennis/Silverthorn
# 81                        The Junction North/Runnymede
# 82                        High Park/The Junction South
# 83                               Parkdale/Roncesvalles
# 84                                   Runnymede/Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87    Business reply mail Processing Centre969 Eastern
# 88          Humber Bay Shores/Mimico South/New Toronto
# 89                               Alderwood/Long Branch
# 90         The Kingsway/Montgomery Road/Old Mill North
# 91   Humber Bay/King's Mill Park/Kingsway Park Sout...
# 92   Kingsway Park South West/Mimico NW/The Queensw...
# 93                                    Islington Avenue
# 94   Cloverdale/Islington/Martin Grove/Princess Gar...
# 95   Bloordale Gardens/Eringate/Markland Wood/Old B...
# 96                                       Humber Summit
# 97                                     Emery/Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village/Martin Grove Gardens/Richvie...
# 101  Albion Gardens/Beaumond Heights/Humbergate/Jam...
# 102                                          Northwest

# %% [markdown]
# ## I extract the content of the file, and modify the string to an array

# %%
url = 'https://cocl.us/Geospatial_data'
html_file=requests.get(url).content

# %%
lonlat=[]
lonlat=html_file.decode('ascii').replace("\r\n",',').split(',')

# %%
len(lonlat)
# Out:
# 312

# %%
a=int(len(lonlat)/3)
x=np.reshape(lonlat, (a,3))

# %%
columns=x[0]
rows=x[1:]

# %%
lonlat_df=pd.DataFrame
lonlat_df=lonlat_df.from_records(rows, columns=columns)

# %%
lonlat_df.rename(columns={'Postal Code':'Postcode'},inplace=True)

# %%
lonlat_df.set_index('Postcode',inplace=True)

# %%
lonlat_df.head()
# Out:
#             Latitude    Longitude
# Postcode
# M1B       43.8066863  -79.1943534
# M1C       43.7845351  -79.1604971
# M1E       43.7635726  -79.1887115
# M1G       43.7709921  -79.2169174
# M1H        43.773136  -79.2394761

# %%
toronto_df.set_index('Postcode',inplace=True)

# %%
toronto_df=toronto_df.join(lonlat_df,how='inner').reset_index()

# %%
toronto_df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood    Latitude  \
# 0                                        Rouge/Malvern  43.8066863
# 1                 Highland Creek/Rouge Hill/Port Union  43.7845351
# 2                      Guildwood/Morningside/West Hill  43.7635726
# 3                                               Woburn  43.7709921
# 4                                            Cedarbrae   43.773136
# 5                                  Scarborough Village  43.7447342
# 6            East Birchmount Park/Ionview/Kennedy Park  43.7279292
# 7                        Clairlea/Golden Mile/Oakridge  43.7111117
# 8        Cliffcrest/Cliffside/Scarborough Village West   43.716316
# 9                           Birch Cliff/Cliffside West   43.692657
# 10   Dorset Park/Scarborough Town Centre/Wexford He...  43.7574096
# 11                                    Maryvale/Wexford  43.7500715
# 12                                           Agincourt  43.7942003
# 13               Clarks Corners/Sullivan/Tam O'Shanter  43.7816375
# 14   Agincourt North/L'Amoreaux East/Milliken/Steel...  43.8152522
# 15                        L'Amoreaux West/Steeles West  43.7995252
# 16                                         Upper Rouge  43.8361247
# 17                                   Hillcrest Village  43.8037622
# 18                          Fairview/Henry Farm/Oriole  43.7785175
# 19                                     Bayview Village  43.7869473
# 20                             Silver Hills/York Mills  43.7574902
# 21                              Newtonbrook/Willowdale   43.789053
# 22                                    Willowdale South  43.7701199
# 23                                     York Mills West  43.7527583
# 24                                     Willowdale West  43.7827364
# 25                                           Parkwoods  43.7532586
# 26                                     Don Mills North  43.7459058
# 27                     Flemingdon Park/Don Mills South  43.7258997
# 28       Bathurst Manor/Downsview North/Wilson Heights  43.7543283
# 29                      Northwood Park/York University  43.7679803
# 30                          CFB Toronto/Downsview East  43.7374732
# 31                                      Downsview West  43.7390146
# 32                                   Downsview Central  43.7284964
# 33                                 Downsview Northwest  43.7616313
# 34                                    Victoria Village  43.7258823
# 35                      Woodbine Gardens/Parkview Hill  43.7063972
# 36                                    Woodbine Heights  43.6953439
# 37                                         The Beaches  43.6763574
# 38                                             Leaside  43.7090604
# 39                                    Thorncliffe Park  43.7053689
# 40                                        East Toronto   43.685347
# 41                         The Danforth West/Riverdale  43.6795571
# 42                       The Beaches West/India Bazaar  43.6689985
# 43                                     Studio District  43.6595255
# 44                                       Lawrence Park  43.7280205
# 45                                    Davisville North  43.7127511
# 46                                  North Toronto West  43.7153834
# 47                                          Davisville  43.7043244
# 48                          Moore Park/Summerhill East  43.6895743
# 49   Deer Park/Forest Hill SE/Rathnelly/South Hill/...  43.6864123
# 50                                            Rosedale  43.6795626
# 51                          Cabbagetown/St. James Town   43.667967
# 52                                Church and Wellesley  43.6658599
# 53                            Harbourfront/Regent Park  43.6542599
# 54                             Ryerson/Garden District  43.6571618
# 55                                      St. James Town  43.6514939
# 56                                         Berczy Park  43.6447708
# 57                                  Central Bay Street  43.6579524
# 58                              Adelaide/King/Richmond  43.6505712
# 59     Harbourfront East/Toronto Islands/Union Station  43.6408157
# 60             Design Exchange/Toronto Dominion Centre  43.6471768
# 61                       Commerce Court/Victoria Hotel  43.6481985
# 62                    Bedford Park/Lawrence Manor East  43.7332825
# 63                                            Roselawn  43.7116948
# 64                  Forest Hill North/Forest Hill West  43.6969476
# 65                   The Annex/North Midtown/Yorkville  43.6727097
# 66                       Harbord/University of Toronto  43.6626956
# 67             Chinatown/Grange Park/Kensington Market  43.6532057
# 68   CN Tower/Bathurst Quay/Island airport/Harbourf...  43.6289467
# 69                     Stn A PO Boxes 25 The Esplanade  43.6464352
# 70               First Canadian Place/Underground city  43.6484292
# 71                     Lawrence Heights/Lawrence Manor   43.718518
# 72                                           Glencairn   43.709577
# 73                                  Humewood-Cedarvale  43.6937813
# 74                                 Caledonia-Fairbanks  43.6890256
# 75                                            Christie   43.669542
# 76                         Dovercourt Village/Dufferin  43.6690051
# 77                             Little Portugal/Trinity  43.6479267
# 78          Brockton/Exhibition Place/Parkdale Village  43.6368472
# 79              Maple Leaf Park/North Park/Upwood Park  43.7137562
# 80         Del Ray/Keelesdale/Mount Dennis/Silverthorn  43.6911158
# 81                        The Junction North/Runnymede  43.6731853
# 82                        High Park/The Junction South  43.6616083
# 83                               Parkdale/Roncesvalles  43.6489597
# 84                                   Runnymede/Swansea  43.6515706
# 85                                        Queen's Park  43.6623015
# 86               Canada Post Gateway Processing Centre  43.6369656
# 87    Business reply mail Processing Centre969 Eastern  43.6627439
# 88          Humber Bay Shores/Mimico South/New Toronto  43.6056466
# 89                               Alderwood/Long Branch  43.6024137
# 90         The Kingsway/Montgomery Road/Old Mill North  43.6536536
# 91   Humber Bay/King's Mill Park/Kingsway Park Sout...  43.6362579
# 92   Kingsway Park South West/Mimico NW/The Queensw...  43.6288408
# 93                                    Islington Avenue  43.6678556
# 94   Cloverdale/Islington/Martin Grove/Princess Gar...  43.6509432
# 95   Bloordale Gardens/Eringate/Markland Wood/Old B...  43.6435152
# 96                                       Humber Summit  43.7563033
# 97                                     Emery/Humberlea  43.7247659
# 98                                              Weston   43.706876
# 99                                           Westmount   43.696319
# 100  Kingsview Village/Martin Grove Gardens/Richvie...  43.6889054
# 101  Albion Gardens/Beaumond Heights/Humbergate/Jam...  43.7394164
# 102                                          Northwest  43.7067483
#
#        Longitude
# 0    -79.1943534
# 1    -79.1604971
# 2    -79.1887115
# 3    -79.2169174
# 4    -79.2394761
# 5    -79.2394761
# 6    -79.2620294
# 7    -79.2845772
# 8    -79.2394761
# 9    -79.2648481
# 10    -79.273304
# 11   -79.2958491
# 12   -79.2620294
# 13   -79.3043021
# 14   -79.2845772
# 15   -79.3183887
# 16   -79.2056361
# 17   -79.3634517
# 18   -79.3465557
# 19    -79.385975
# 20   -79.3747141
# 21   -79.4084928
# 22   -79.4084928
# 23   -79.4000493
# 24   -79.4422593
# 25   -79.3296565
# 26    -79.352188
# 27    -79.340923
# 28   -79.4422593
# 29   -79.4872619
# 30   -79.4647633
# 31   -79.5069436
# 32   -79.4956974
# 33   -79.5209994
# 34   -79.3155716
# 35    -79.309937
# 36   -79.3183887
# 37   -79.2930312
# 38   -79.3634517
# 39   -79.3493719
# 40   -79.3381065
# 41    -79.352188
# 42   -79.3155716
# 43    -79.340923
# 44   -79.3887901
# 45   -79.3901975
# 46   -79.4056784
# 47   -79.3887901
# 48   -79.3831599
# 49   -79.4000493
# 50   -79.3775294
# 51   -79.3676753
# 52   -79.3831599
# 53   -79.3606359
# 54   -79.3789371
# 55   -79.3754179
# 56   -79.3733064
# 57   -79.3873826
# 58   -79.3845675
# 59   -79.3817523
# 60   -79.3815764
# 61   -79.3798169
# 62   -79.4197497
# 63   -79.4169356
# 64   -79.4113072
# 65   -79.4056784
# 66   -79.4000493
# 67   -79.4000493
# 68   -79.3944199
# 69    -79.374846
# 70   -79.3822802
# 71   -79.4647633
# 72   -79.4450726
# 73   -79.4281914
# 74    -79.453512
# 75   -79.4225637
# 76   -79.4422593
# 77   -79.4197497
# 78   -79.4281914
# 79   -79.4900738
# 80   -79.4760133
# 81   -79.4872619
# 82   -79.4647633
# 83    -79.456325
# 84   -79.4844499
# 85   -79.3894938
# 86    -79.615819
# 87    -79.321558
# 88   -79.5013207
# 89   -79.5434841
# 90   -79.5069436
# 91   -79.4985091
# 92   -79.5209994
# 93   -79.5322424
# 94   -79.5547244
# 95   -79.5772008
# 96   -79.5659633
# 97   -79.5322424
# 98   -79.5181884
# 99   -79.5322424
# 100  -79.5547244
# 101  -79.5884369
# 102  -79.5940544
